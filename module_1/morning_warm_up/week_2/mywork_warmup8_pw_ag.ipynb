# %%
### ""Pair-coded by Allan Kim Gayahan and Phoebe Wong :)""
### 1. Go to https://www.kaggle.com/russellyates88/suicide-rates-overview-1985-to-2016 and download the data 
import pandas as pd
import numpy as np
df = pd.read_csv('master.csv')
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
# !pwd
# !mv /Users/phoebe/Downloads/master.csv /Users/phoebe/FlatIron/dc_ds_06_03_19/module_1/morning_warm_up/week_2/suicide_rates.csv
# Out:
# /Users/phoebe/FlatIron/dc_ds_06_03_19/module_1/morning_warm_up/week_2

# %%
# !ls
# Out:
# 2_2_simulation_np_random_n_dict.md mywork_warmup5_pw.ipynb
# 2_3_cat_n_normalize.md             mywork_warmup5_pw.py
# 2_4_visualization_matplotlib.md    mywork_warmup6_pw.ipynb
# 2_5_apply_lambda_gb_plt.md         mywork_warmup7_pw.ipynb
# 2_6_histogram_lr_creation.md       mywork_warmup8_pw.ipynb
# Untitled.ipynb                     plots
# co2_2.csv                          suicide_rates.csv
# master.csv                         suicides.csv

# %%
### 2. Use command line to rename the downloaded file to suicide_rates.csv, then move the file to your repository 
###mv' `

### 3. Load the data into a pandas dataframe
df= pd.read_csv('suicide_rates.csv')
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
df['country'].value_counts()
# Out:
# Mauritius                 382
# Iceland                   382
# Netherlands               382
# Austria                   382
# Brazil                    372
# Greece                    372
# United Kingdom            372
# Singapore                 372
# Puerto Rico               372
# Malta                     372
# Ecuador                   372
# Mexico                    372
# Japan                     372
# Colombia                  372
# Belgium                   372
# Italy                     372
# Argentina                 372
# United States             372
# Israel                    372
# Spain                     372
# Chile                     372
# Republic of Korea         372
# Luxembourg                372
# Bulgaria                  360
# Costa Rica                360
# Australia                 360
# France                    360
# Guatemala                 360
# Norway                    360
# Ireland                   360
#                          ...
# ...

# %%
### 4. Pick only rows where country starts with 'U' 
dfu=df.loc[df['country'].apply(lambda x: x[0] == "U")]

# %%
### 5. Get the names of unique countries left - `use .unique()`
dfu['country'].unique()
# Out:
# array(['Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan'], dtype=object)

# %%
dfu['country'].value_counts()
# Out:
# United States           372
# United Kingdom          372
# Ukraine                 336
# Uruguay                 336
# Uzbekistan              264
# United Arab Emirates     72
# Name: country, dtype: int64

# %%
##### [Thoughts]: how would that be useful if we have duplicated values in a dataset?

# %%
### 6. Pick only rows with 'United States' (without using apply or lambda - try using indexing)
#dfb = df[df['A']==5].index.values.astype(int)
dfi = dfu[dfu['country']== 'United States'].index.values.astype(int)
dfi
# Out:
# array([26848, 26849, 26850, 26851, 26852, 26853, 26854, 26855, 26856,
#        26857, 26858, 26859, 26860, 26861, 26862, 26863, 26864, 26865,
#        26866, 26867, 26868, 26869, 26870, 26871, 26872, 26873, 26874,
#        26875, 26876, 26877, 26878, 26879, 26880, 26881, 26882, 26883,
#        26884, 26885, 26886, 26887, 26888, 26889, 26890, 26891, 26892,
#        26893, 26894, 26895, 26896, 26897, 26898, 26899, 26900, 26901,
#        26902, 26903, 26904, 26905, 26906, 26907, 26908, 26909, 26910,
#        26911, 26912, 26913, 26914, 26915, 26916, 26917, 26918, 26919,
#        26920, 26921, 26922, 26923, 26924, 26925, 26926, 26927, 26928,
#        26929, 26930, 26931, 26932, 26933, 26934, 26935, 26936, 26937,
#        26938, 26939, 26940, 26941, 26942, 26943, 26944, 26945, 26946,
#        26947, 26948, 26949, 26950, 26951, 26952, 26953, 26954, 26955,
#        26956, 26957, 26958, 26959, 26960, 26961, 26962, 26963, 26964,
# ...

# %%
dfu.loc[dfi,:]
# Out:
#              country  year     sex          age  suicides_no  population  \
# 26848  United States  1985    male    75+ years         2177     4064000
# 26849  United States  1985    male  55-74 years         5302    17971000
# 26850  United States  1985    male  25-34 years         5134    20986000
# 26851  United States  1985    male  35-54 years         6053    26589000
# 26852  United States  1985    male  15-24 years         4267    19962000
# 26853  United States  1985  female  35-54 years         2105    27763000
# 26854  United States  1985  female  55-74 years         1568    21366000
# 26855  United States  1985  female    75+ years          466     7469000
# 26856  United States  1985  female  25-34 years         1242    21041000
# 26857  United States  1985  female  15-24 years          854    19589000
# 26858  United States  1985    male   5-14 years          205    17370000
# 26859  United States  1985  female   5-14 years           73    16553000
# ...

# %%
### 6. Group by age column and sum # suicides
dfu.groupby(['age'])['suicides_no'].sum()
# Out:
# age
# 15-24 years    195656
# 25-34 years    268759
# 35-54 years    574686
# 5-14 years      12596
# 55-74 years    352590
# 75+ years      135044
# Name: suicides_no, dtype: int64

# %%
### 7. Change the age column to a categorical one 
dfu['agedummy']= dfu['age'].astype('category')
# Out:
# /Users/phoebe/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dfu.head()
# Out:
#        country  year     sex          age  suicides_no  population  \
# 26068  Ukraine  1987    male    75+ years          506      654800
# 26069  Ukraine  1987    male  55-74 years         1934     3652600
# 26070  Ukraine  1987    male  35-54 years         3093     6206800
# 26071  Ukraine  1987    male  25-34 years         1383     3890300
# 26072  Ukraine  1987  female    75+ years          486     1816100
#
#        suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 26068              77.28  Ukraine1987           NaN     64,087,694,038
# 26069              52.95  Ukraine1987           NaN     64,087,694,038
# 26070              49.83  Ukraine1987           NaN     64,087,694,038
# 26071              35.55  Ukraine1987           NaN     64,087,694,038
# 26072              26.76  Ukraine1987           NaN     64,087,694,038
#
#        gdp_per_capita ($)       generation     agedummy
# 26068                1353  G.I. Generation    75+ years
# ...

# %%
cat = list(dfu.agedummy.unique())
cat
# Out:
# ['75+ years',
#  '55-74 years',
#  '35-54 years',
#  '25-34 years',
#  '15-24 years',
#  '5-14 years']

# %%
tips.total_bin.cat.reorder_categories(tips.total_bin.cat.categories[::-1],inplace=True)

# %%
### 8. Re-order the categories so that 5-14 years appears first 
dfu['sorted']=dfu.agedummy.cat.reorder_categories(['5-14 years','15-24 years','25-34 years','35-54 years','55-74 years','75+ years'], ordered= False)
dfus = dfu.sort_values(by='agedummy').copy()
dfus.head(20)
# Out:
# /Users/phoebe/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#               country  year     sex         age  suicides_no  population  \
# 26943   United States  1992  female  5-14 years           82    17783300
# 26918   United States  1990    male  5-14 years          195    17970800
# 27122   United States  2007    male  5-14 years          131    20659096
# 27123   United States  2007  female  5-14 years           53    19714203
# 26594  United Kingdom  1994    male  5-14 years            9     3837961
# 26319         Ukraine  2007  female  5-14 years           11     2155250
# 26318         Ukraine  2007    male  5-14 years           39     2268187
# ...

# %%
print(grouped['female'][1])

# %%
### 9. Draw a barplot of # suicides(y) per age-group (x) for 2015
dfu2015=dfu.loc[dfu['year']==2015].groupby(['agedummy'])['suicides_no'].sum()
dfu2015
# a=dfu.groupby(['agedummy','year'])['suicides_no'].sum()
# a
# a['agedummy'][2015]
# Out:
# agedummy
# 5-14 years       480
# 15-24 years     6684
# 25-34 years     9125
# 35-54 years    20520
# 55-74 years    15362
# 75+ years       5132
# Name: suicides_no, dtype: int64

# %%
dfu2015.values
# Out:
# array([  480,  6684,  9125, 20520, 15362,  5132])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.barplot(x=dfu2015.index, y=dfu2015.values)

# %%
### 10. Save the plot to the visualization folder we have created
plt.savefig('suicidebar.jpg')

# %%
### 11. Push all to your git branch.
