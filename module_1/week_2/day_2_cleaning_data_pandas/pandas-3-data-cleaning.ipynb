# %% [markdown]
# # Data Cleaning with Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Scenario
#
# As data scientists, we want to build a model to predict the sale price of a house in Seattle in 2019, based on its square footage. We know that the King County Department of Assessments has comprehensive data available on real property sales in the Seattle area. We need to prepare the data.

# %% [markdown]
# ### First, get the data!
#
# When working on a project involving data that can fit on our computer, we store it in a `data` directory.
#
# ```bash
# cd <project_directory>  # example: cd ~/flatiron_ds/pandas-3
# mkdir data
# cd data
# ```
#
# Note that `<project_directory>` in angle brackets is a _placeholder_. You should type the path to the actual location on your computer where you're working on this project. Do not literally type `<project_directory>` and _do not type the angle brackets_. You can see an example in the _comment_ to the right of the command above.
#
# Now, we'll need to download the two data files that we need. We can do this at the command line:
#
# ```bash
# wget https://aqua.kingcounty.gov/extranet/assessor/Real%20Property%20Sales.zip
# wget https://aqua.kingcounty.gov/extranet/assessor/Residential%20Building.zip
# ```
#
# *Note:* If you do not have the `wget` command yet, you can install it with `brew install wget`, or use `curl <url> -o <filename>`.
#
# Note that `%20` in a URL translates into a space. Even though you will *never put spaces in filenames*, you may need to deal with spaces that _other_ people have used in filenames.
#
# There are two ways to handle the spaces in these filenames when referencing them at the command line.

# %% [markdown]
# #### 1. You can _escape_ the spaces by putting a backslash (`\`, remember _backslash is next to backspace_) before each one:
#
# `unzip Real\ Property\ Sales.zip`
#
# This is what happens if you tab-complete the filename in the terminal. Tab completion is your friend!

# %% [markdown]
# #### 2. You can put the entire filename in quotes:
#
# `unzip "Real Property Sales.zip"`
#
# Try unzipping these files with the `unzip` command. The `unzip` command takes one argument, the name of the file that you want to unzip.

# %%
sales_df = pd.read_csv('EXTR_RPSale.csv')

# %% [markdown]
# ### Seeing pink? Warnings are useful!
#
# Note the warning above: `DtypeWarning: Columns (1, 2) have mixed types.` Because we start with an index of zero, the columns that we're being warned about are actually the _second_ and _third_ columns, `sales_df['Major']` and `sales_df['Minor']`.

# %%
sales_df.head()
# Out:
#    ExciseTaxNbr   Major Minor DocumentDate  SalePrice    RecordingNbr Volume  \
# 0       2687551  138860   110   08/21/2014     245000  20140828001436
# 1       1235111  664885    40   07/09/1991          0  199203161090      071
# 2       2704079  423943    50   10/11/2014          0  20141205000558
# 3       2584094  403700   715   01/04/2013          0  20130110000910
# 4       1056831  951120   900   04/20/1989      85000  198904260448      117
#
#   Page PlatNbr PlatType  ... PropertyType PrincipalUse SaleInstrument  \
# 0                        ...            3            6              3
# 1  001  664885        C  ...            3            0             26
# 2                        ...            3            6             15
# 3                        ...            3            6             15
# 4  053  951120        P  ...            3            0              2
#
#   AFForestLand  AFCurrentUseLand  AFNonProfitUse  AFHistoricProperty  \
# 0            N                 N               N                   N
# 1            N                 N               N                   N
# 2            N                 N               N                   N
# 3            N                 N               N                   N
# 4            N                 N               N                   N
#
#   SaleReason PropertyClass SaleWarning
# 0          1             8
# 1         18             3          11
# 2         18             8    18 31 51
# 3         11             8    18 31 38
# 4          1             9          49
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Data overload?
#
# That's a lot of columns. We're only interested in identifying the date, sale price, and square footage of each specific property. What can we do?

# %%
small_sales_df = sales_df[['Major', 'Minor', 'DocumentDate', 'SalePrice']].copy()

# %%
small_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2026164 entries, 0 to 2026163
# Data columns (total 4 columns):
# Major           float64
# Minor           float64
# DocumentDate    object
# SalePrice       int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 61.8+ MB

# %%
sales_df.DocumentDate.describe()
# Out:
# count        2026164
# unique         14257
# top       06/11/2014
# freq             951
# Name: DocumentDate, dtype: object

# %%
sales_df.Major.describe()
# Out:
# count     2026164
# unique      28590
# top             0
# freq         9362
# Name: Major, dtype: int64

# %%
bldg_df = pd.read_csv('EXTR_ResBldg.csv')
# Out:
# /Users/phoebe/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Another warning! Which column has index 11?

# %%
bldg_df.ZipCode.describe()
# Out:
# count     468423
# unique       292
# top        98115
# freq       11579
# Name: ZipCode, dtype: object

# %%
bldg_df.columns[11]
# Out:
# 'ZipCode'

# %% [markdown]
# `ZipCode` seems like a potentially useful column. We'll need it to determine which house sales took place in Seattle.

# %%
bldg_df.head().T
# Out:
#                                             0                           1  \
# Major                                   62304                       62304
# Minor                                    9347                        9378
# BldgNbr                                     1                           1
# NbrLivingUnits                              1                           1
# Address              907  SW 104TH ST   98146  10215   11TH AVE SW  98146
# BuildingNumber                          907                         10215
# Fraction
# DirectionPrefix                            SW
# StreetName          104TH                       11TH
# StreetType                             ST                          AVE
# DirectionSuffix                                                        SW
# ZipCode                                 98146                       98146
# Stories                                     1                           1
# BldgGrade                                   7                           7
# BldgGradeVar                                0                           0
# SqFt1stFloor                             1180                         970
# SqFtHalfFloor                               0                           0
# SqFt2ndFloor                                0                           0
# SqFtUpperFloor                              0                           0
# SqFtUnfinFull                               0                           0
# SqFtUnfinHalf                               0                           0
# SqFtTotLiving                            1570                         970
# SqFtTotBasement                           670                           0
# SqFtFinBasement                           390                           0
# FinBasementGrade                            6                           0
# SqFtGarageBasement                          0                           0
# SqFtGarageAttached                          0                         380
# DaylightBasement                                                        N
# SqFtOpenPorch                             150                           0
# SqFtEnclosedPorch                           0                          80
# SqFtDeck                                    0                           0
# HeatSystem                                  5                           5
# HeatSource                                  2                           2
# BrickStone                                  0                           0
# ViewUtilization                                                         N
# Bedrooms                                    3                           3
# BathHalfCount                               0                           0
# Bath3qtrCount                               0                           1
# BathFullCount                               1                           1
# FpSingleStory                               1                           1
# FpMultiStory                                0                           0
# FpFreestanding                              0                           0
# FpAdditional                                0                           0
# YrBuilt                                  1965                        1969
# YrRenovated                                 0                           0
# PcntComplete                                0                           0
# Obsolescence                                0                           0
# PcntNetCondition                            0                           0
# Condition                                   3                           3
# AddnlCost                                   0                           0
#
#                                             2                           3  \
# Major                                   62304                       62306
# Minor                                    9394                        9034
# BldgNbr                                     1                           1
# NbrLivingUnits                              1                           1
# Address              510  SW 108TH ST   98146  18809  SE 109TH ST   98027
# BuildingNumber                          510                         18809
# Fraction
# DirectionPrefix                            SW                          SE
# StreetName          108TH                       109TH
# StreetType                             ST                          ST
# DirectionSuffix
# ZipCode                                 98146                       98027
# Stories                                     1                         1.5
# BldgGrade                                   7                           6
# BldgGradeVar                                0                           0
# SqFt1stFloor                             1260                        1730
# SqFtHalfFloor                               0                         450
# SqFt2ndFloor                                0                           0
# SqFtUpperFloor                              0                           0
# SqFtUnfinFull                               0                         990
# SqFtUnfinHalf                               0                           0
# SqFtTotLiving                            1710                        1190
# SqFtTotBasement                          1220                         810
# SqFtFinBasement                           450                           0
# FinBasementGrade                            7                           0
# SqFtGarageBasement                        570                           0
# SqFtGarageAttached                          0                           0
# DaylightBasement                            Y                           Y
# SqFtOpenPorch                               0                           0
# SqFtEnclosedPorch                           0                           0
# SqFtDeck                                  510                         360
# HeatSystem                                  4                           6
# HeatSource                                  3                           3
# BrickStone                                  0                           0
# ViewUtilization                                                         N
# Bedrooms                                    3                           3
# BathHalfCount                               0                           0
# Bath3qtrCount                               1                           0
# BathFullCount                               1                           1
# FpSingleStory                               0                           0
# FpMultiStory                                0                           0
# FpFreestanding                              0                           0
# FpAdditional                                0                           0
# YrBuilt                                  1979                        1934
# YrRenovated                                 0                           0
# PcntComplete                                0                           0
# Obsolescence                                0                           0
# PcntNetCondition                            0                           0
# Condition                                   3                           4
# AddnlCost                                   0                           0
#
#                                                        4
# Major                                              62306
# Minor                                               9036
# BldgNbr                                                1
# NbrLivingUnits                                         1
# Address             11128   RENTON-ISSAQUAH RD SE  98027
# BuildingNumber                                     11128
# Fraction
# DirectionPrefix
# StreetName                     RENTON-ISSAQUAH
# StreetType                                        RD
# DirectionSuffix                                       SE
# ZipCode                                            98027
# Stories                                                1
# BldgGrade                                              8
# BldgGradeVar                                           0
# SqFt1stFloor                                        2000
# SqFtHalfFloor                                          0
# SqFt2ndFloor                                           0
# SqFtUpperFloor                                         0
# SqFtUnfinFull                                          0
# SqFtUnfinHalf                                          0
# SqFtTotLiving                                       2000
# SqFtTotBasement                                        0
# SqFtFinBasement                                        0
# FinBasementGrade                                       0
# SqFtGarageBasement                                     0
# SqFtGarageAttached                                   600
# DaylightBasement                                       N
# SqFtOpenPorch                                        160
# SqFtEnclosedPorch                                      0
# SqFtDeck                                             350
# HeatSystem                                             5
# HeatSource                                             2
# BrickStone                                             0
# ViewUtilization                                        N
# Bedrooms                                               3
# BathHalfCount                                          1
# Bath3qtrCount                                          1
# BathFullCount                                          2
# FpSingleStory                                          0
# FpMultiStory                                           0
# FpFreestanding                                         0
# FpAdditional                                           0
# YrBuilt                                             1988
# YrRenovated                                            0
# PcntComplete                                           0
# Obsolescence                                           0
# PcntNetCondition                                       0
# Condition                                              4
# AddnlCost                                              0

# %% [markdown]
# ### So many features!
#
# As data scientists, we should be _very_ cautious about discarding potentially useful data. But, today, we're interested in _only_ the total square footage of each property. What can we do?

# %%
small_bldg_df = bldg_df[['Major', 'Minor', 'SqFtTotLiving', 'ZipCode']].copy()

# %%
small_bldg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512114 entries, 0 to 512113
# Data columns (total 4 columns):
# Major            512114 non-null int64
# Minor            512114 non-null int64
# SqFtTotLiving    512114 non-null int64
# ZipCode          468423 non-null object
# dtypes: int64(3), object(1)
# memory usage: 15.6+ MB

# %%
sales_data = pd.merge(small_sales_df, small_bldg_df, on=['Major', 'Minor'])

# %%
sales_data.head()
# Out:
#       Major  Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode
# 0  138860.0  110.0   08/21/2014     245000           1490   98002
# 1  138860.0  110.0   06/12/1989     109300           1490   98002
# 2  138860.0  110.0   01/16/2005      14684           1490   98002
# 3  138860.0  110.0   06/08/2005          0           1490   98002
# 4  423943.0   50.0   10/11/2014          0            960   98092

# %%
sales_data.Major.describe()
# Out:
# count    1.446234e+06
# mean     4.481679e+05
# std      2.870434e+05
# min      4.000000e+01
# 25%      2.018700e+05
# 50%      3.832500e+05
# 75%      7.228500e+05
# max      9.906000e+05
# Name: Major, dtype: float64

# %%
sales_data.Minor.describe()
# Out:
# count    1.446234e+06
# mean     1.603629e+03
# std      2.885767e+03
# min      1.000000e+00
# 25%      1.200000e+02
# 50%      3.350000e+02
# 75%      1.060000e+03
# max      9.692000e+03
# Name: Minor, dtype: float64

# %%
sales_data.ZipCode.describe()
# Out:
# count     1286267
# unique        282
# top         98042
# freq        32844
# Name: ZipCode, dtype: object

# %%
sales_data.Major.dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Error!
#
# Why are we seeing an error when we try to join the dataframes?
#
# <table>
#     <tr>
#         <td style="text-align:left"><pre>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2013160 entries, 0 to 2013159
# Data columns (total 4 columns):
# Major           object
# Minor           object
# DocumentDate    object
# SalePrice       int64
# dtypes: int64(1), object(3)
# memory usage: 61.4+ MB</pre></td>
#         <td style="text-align:left"><pre>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511359 entries, 0 to 511358
# Data columns (total 4 columns):
# Major            511359 non-null int64
# Minor            511359 non-null int64
# SqFtTotLiving    511359 non-null int64
# ZipCode          468345 non-null object
# dtypes: int64(3), object(1)
# memory usage: 15.6+ MB
# </pre></td>
#     </tr>
# </table>
#
# Review the error message in light of the above:
#
# * `ValueError: You are trying to merge on object and int64 columns.`

# %%
sales_df['Major'] = pd.to_numeric(sales_df['Major'])

# %% [markdown]
# ### Error!
#
# Note the useful error message above:
#
# `ValueError: Unable to parse string "      " at position 936643`
#
# In this case, we want to treat non-numeric values as missing values. Let's see if there's a way to change how the `pd.to_numeric` function handles errors.

# %%
# The single question mark means "show me the docstring"
pd.to_numeric?

# %% [markdown]
# Here's the part that we're looking for:
# ```
# errors : {'ignore', 'raise', 'coerce'}, default 'raise'
#     - If 'raise', then invalid parsing will raise an exception
#     - If 'coerce', then invalid parsing will be set as NaN
#     - If 'ignore', then invalid parsing will return the input
# ```
#
# Let's try setting the `errors` parameter to `'coerce'`.

# %%
small_sales_df['Major'] = pd.to_numeric(small_sales_df['Major'], errors='coerce')

# %% [markdown]
# Did it work?

# %%
small_sales_df.Major.dtype
# Out:
# dtype('float64')

# %%
small_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2026164 entries, 0 to 2026163
# Data columns (total 4 columns):
# Major           float64
# Minor           float64
# DocumentDate    object
# SalePrice       int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 61.8+ MB

# %% [markdown]
# It worked! Let's do the same thing with the `Minor` parcel number.

# %%
small_sales_df['Minor'] = pd.to_numeric(small_sales_df['Minor'], errors='coerce')

# %%
small_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2026164 entries, 0 to 2026163
# Data columns (total 4 columns):
# Major           float64
# Minor           float64
# DocumentDate    object
# SalePrice       int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 61.8+ MB

# %% [markdown]
# Now, let's try our join again.

# %%
sales_data = pd.merge(small_sales_df, small_bldg_df, on=['Major', 'Minor'])

# %%
sales_data.head()
# Out:
#       Major  Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode
# 0  138860.0  110.0   08/21/2014     245000           1490   98002
# 1  138860.0  110.0   06/12/1989     109300           1490   98002
# 2  138860.0  110.0   01/16/2005      14684           1490   98002
# 3  138860.0  110.0   06/08/2005          0           1490   98002
# 4  423943.0   50.0   10/11/2014          0            960   98092

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1446234 entries, 0 to 1446233
# Data columns (total 6 columns):
# Major            1446234 non-null float64
# Minor            1446234 non-null float64
# DocumentDate     1446234 non-null object
# SalePrice        1446234 non-null int64
# SqFtTotLiving    1446234 non-null int64
# ZipCode          1329081 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 77.2+ MB

# %% [markdown]
# We can see right away that we're missing zip codes for many of the sales transactions. (1321536 non-null entries for ZipCode is fewer than the 1436772 entries in the dataframe.)

# %%
sales_data.loc[sales_data['ZipCode'].isna()].head()
# Out:
#        Major   Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode
# 91  334330.0  1343.0   05/30/2006          0           4600     NaN
# 92  334330.0  1343.0   05/30/2006          0           4600     NaN
# 93  334330.0  1343.0   11/26/2001          0           4600     NaN
# 94  334330.0  1343.0   05/30/2006          0           4600     NaN
# 95  334330.0  1343.0   06/30/2016          0           4600     NaN

# %% [markdown]
# Because we are interested in finding houses in Seattle zip codes, we will need to drop the rows with missing zip codes.

# %%
sales_data = sales_data.loc[~sales_data['ZipCode'].isna(), :]

sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1329081 entries, 0 to 1446233
# Data columns (total 6 columns):
# Major            1329081 non-null float64
# Minor            1329081 non-null float64
# DocumentDate     1329081 non-null object
# SalePrice        1329081 non-null int64
# SqFtTotLiving    1329081 non-null int64
# ZipCode          1329081 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 71.0+ MB

# %% [markdown]
# # Your turn: Data Cleaning with Pandas

# %% [markdown]
# ### 1. Investigate and drop rows with invalid values in the SalePrice and SqFtTotLiving columns.
#
# Use multiple notebook cells to accomplish this! Press `[esc]` then `B` to create a new cell below the current cell. Press `[return]` to start typing in the new cell.

# %%
sales_data = sales_data.loc[~sales_data['SalePrice'].isna(), :]
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1329081 entries, 0 to 1446233
# Data columns (total 6 columns):
# Major            1329081 non-null float64
# Minor            1329081 non-null float64
# DocumentDate     1329081 non-null object
# SalePrice        1329081 non-null int64
# SqFtTotLiving    1329081 non-null int64
# ZipCode          1329081 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 71.0+ MB

# %%
sales_data1 = sales_data.loc[sales_data['SalePrice'] != 0, :].copy()
sales_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 872118 entries, 0 to 1446233
# Data columns (total 6 columns):
# Major            872118 non-null float64
# Minor            872118 non-null float64
# DocumentDate     872118 non-null object
# SalePrice        872118 non-null int64
# SqFtTotLiving    872118 non-null int64
# ZipCode          872118 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 46.6+ MB

# %%
sales_data2 = sales_data1.loc[~sales_data['SqFtTotLiving'].isna(), :].copy()
sales_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 872118 entries, 0 to 1446233
# Data columns (total 6 columns):
# Major            872118 non-null float64
# Minor            872118 non-null float64
# DocumentDate     872118 non-null object
# SalePrice        872118 non-null int64
# SqFtTotLiving    872118 non-null int64
# ZipCode          872118 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 46.6+ MB

# %%
sales_data3 = sales_data2.loc[sales_data['SqFtTotLiving'] != 0, :].copy()
sales_data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 872106 entries, 0 to 1446233
# Data columns (total 6 columns):
# Major            872106 non-null float64
# Minor            872106 non-null float64
# DocumentDate     872106 non-null object
# SalePrice        872106 non-null int64
# SqFtTotLiving    872106 non-null int64
# ZipCode          872106 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 46.6+ MB

# %% [markdown]
# ### 2. Investigate and handle non-numeric ZipCode values
#
# Can you find a way to shorten ZIP+4 codes to the first five digits?
#
# What's the right thing to do with missing values?

# %%
a = 'string'
a[0]
b = []
b.append(a[0])
b
# Out:
# ['s']

# %%
a=list("98199-3014")
a[0]
len(a)
# Out:
# 10

# %%
del(a[5:10])
a
# Out:
# ['9', '8', '1', '9', '9']

# %%
s = "".join(a)
s
# Out:
# '98199'

# %%
# Read the error message and decide how to fix it.
# Note: using errors='coerce' is the *wrong* choice in this case.
def is_integer(x):
    try:
        _ = int(x)
    except ValueError:
        return False
    return True

sales_data.loc[sales_data['ZipCode'].apply(is_integer) == False, 'ZipCode'].head()
# Out:
# 14502    98199-3014
# 14503    98199-3014
# 14504    98199-3014
# 23823    98031-3173
# 24355    98042-3001
# Name: ZipCode, dtype: object

# %%
sales_data['ZipCode'][14502]
# Out:
# '98199-3014'

# %%
a='98199'
str(a)
# Out:
# '98199'

# %%
def short(x):
    a = list(str(x))
    if len(a)>5:
        del(a[5:10])
        s = "".join(a)
    else:
        s = str(x)
    return s

# %%
p = '98132-0000'
short(p)
# Out:
# '98132'

# %%
sales_data3['ZipCode']= sales_data3['ZipCode'].map(short).copy()
sales_data3['ZipCode'][14502]
# Out:
# '98199'

# %%
sales_data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 872106 entries, 0 to 1446233
# Data columns (total 6 columns):
# Major            872106 non-null float64
# Minor            872106 non-null float64
# DocumentDate     872106 non-null object
# SalePrice        872106 non-null int64
# SqFtTotLiving    872106 non-null int64
# ZipCode          872106 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 86.6+ MB

# %% [markdown]
# ### 3. Add a column for PricePerSqFt

# %%
sales_data3['PricePerSqFt'] = sales_data3['SalePrice']/sales_data3['SqFtTotLiving']
sales_data3['PricePerSqFt']
# Out:
# 0           164.429530
# 1            73.355705
# 2             9.855034
# 6           100.000000
# 7           132.812500
# 11          260.955056
# 12          200.561798
# 13           79.775281
# 14          296.629213
# 16           68.268293
# 17          214.390244
# 19          151.583710
# 20          167.375566
# 21           87.307692
# 22          167.375566
# 23           48.642534
# 25          102.916667
# 26           94.093137
# 27          142.132353
# 29          177.551020
# 31          137.755102
# 32          214.285714
# 33          151.020408
# 34           89.201878
# 36          158.685446
# 38          118.577075
# 39          154.150198
# 40         1166.666667
# 42          119.444444
# 44          150.000000
#               ...
# 1446190     227.174030
# 1446193      55.184049
# 1446194     140.625000
# 1446195     384.615385
# 1446197     167.465753
# 1446198      37.373737
# 1446199      43.216080
# 1446200      73.732719
# 1446201     116.477273
# 1446202     103.658537
# 1446203     185.095420
# 1446204      56.666667
# 1446208     157.484507
# 1446209      41.530055
# 1446210      40.860215
# 1446214     111.111111
# 1446216      44.223827
# 1446217     153.571429
# 1446219     240.540541
# 1446220     127.995169
# 1446221      64.250000
# 1446223     143.081761
# 1446224      42.852206
# 1446225      72.662338
# 1446226      82.129964
# 1446227      73.770492
# 1446228      97.626316
# 1446229      40.875912
# 1446232     302.272727
# 1446233      40.909091
# Name: PricePerSqFt, Length: 872106, dtype: float64

# %%
sales_data3['SalePrice'][0]
# Out:
# 245000

# %%
sales_data3['SqFtTotLiving'][0]
# Out:
# 1490

# %%
245000/1490
# Out:
# 164.4295302013423

# %% [markdown]
# ### 4. Subset the data to 2019 sales only.
#
# We can assume that the DocumentDate is approximately the sale date.

# %%
sales_data3['DATE']=pd.to_datetime(sales_data3['DocumentDate'])

# %%
sales_data3['DATE']
# Out:
# 0         2014-08-21
# 1         1989-06-12
# 2         2005-01-16
# 6         1999-07-15
# 7         2001-01-08
# 11        2013-07-03
# 12        2013-02-21
# 13        1995-10-13
# 14        2007-02-22
# 16        1994-03-23
# 17        2017-03-29
# 19        2012-06-07
# 20        2013-08-26
# 21        1994-06-27
# 32         214.285714    False 2004-04-30  2004    None
# 33         151.020408    False 2012-12-21  2012    None
# 34          89.201878    False 2015-07-14  2015    True
# 36         158.685446    False 2015-12-21  2015    True
# 38         118.577075    False 1997-02-21  1997    None
# 39         154.150198    False 2000-11-28  2000    None
# 40        1166.666667    False 2004-05-10  2004    None
# 42         119.444444    False 2013-10-24  2013    None
# 44         150.000000    False 2004-09-20  2004    None
# ...               ...      ...        ...   ...     ...
# 1446190    227.174030    False 2014-08-05  2014    None
# 1446193     55.184049    False 1986-12-11  1986    True
# 1446194    140.625000    False 2003-07-03  2003    None
# 1446195    384.615385    False 2016-11-04  2016    True
# 1446197    167.465753    False 2002-10-07  2002    True
# 1446198     37.373737    False 1986-12-12  1986    True
# 1446199     43.216080    False 1988-03-09  1988    None
# 1446200     73.732719    False 1997-11-10  1997    True
# 1446201    116.477273    False 2003-05-06  2003    None
# 1446202    103.658537    False 1994-07-25  1994    None
# 1446203    185.095420    False 2005-04-15  2005    None
# 1446204     56.666667    False 1984-06-01  1984    None
# 1446208    157.484507    False 2003-10-06  2003    None
# 1446209     41.530055    False 1986-06-25  1986    None
# 1446210     40.860215    False 1988-12-23  1988    None
# 1446214    111.111111    False 1999-12-22  1999    True
# 1446216     44.223827    False 1985-04-22  1985    None
# 1446217    153.571429    False 1992-12-01  1992    True
# 1446219    240.540541    False 2003-09-25  2003    True
# 1446220    127.995169    False 1996-07-26  1996    True
# 1446221     64.250000    False 1989-09-05  1989    True
# 1446223    143.081761    False 1991-04-19  1991    True
# 1446224     42.852206    False 1987-08-07  1987    None
# 1446225     72.662338    False 1986-12-29  1986    True
# 1446226     82.129964    False 1993-03-31  1993    None
# 1446227     73.770492    False 1988-01-12  1988    True
# 1446228     97.626316    False 1997-11-10  1997    None
# 1446229     40.875912    False 1984-03-14  1984    True
# 1446232    302.272727    False 2014-03-24  2014    None
# 1446233     40.909091    False 1986-02-14  1986    None
#
# [872106 rows x 11 columns]

# %%
sales_data3['Year'].value_counts()
# Out:
# 2004    42525
# 2005    41320
# 2003    40401
# 1998    36795
# 1999    35537
# 2002    34911
# 1997    34753
# 2006    34625
# 2000    32889
# 2001    32357
# 1994    31091
# 1992    30616
# 1996    30300
# 1993    30052
# 2016    28359
# 2017    28010
# 2015    27976
# 2013    27339
# 1995    26963
# 2007    26483
# 2014    25887
# 2018    24773
# 2012    22821
# 2011    17680
# 2008    16899
# 2010    16630
# 2009    16118
# 1989    10133
# 1991     8985
# 2019     8351
#         ...
# 1984     4990
# 1983     4311
# 1982     2537
# 1981       99
# 1980       10
# 1979       10
# 1978       10
# 1975        9
# 1977        8
# 1964        7
# 1976        7
# 1966        5
# 1965        5
# 1974        4
# 1971        4
# 1970        4
# 1967        4
# 1973        4
# 1962        3
# 1972        3
# 1969        3
# 1968        3
# 1959        1
# 1954        1
# 1955        1
# 2021        1
# 1960        1
# 1961        1
# 1963        1
# 1934        1
# Name: Year, Length: 65, dtype: int64

# %%
sales_data3.loc[sales_data3['Year']== 2019]
# Out:
#             Major   Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode  \
#
# 1442879    229.591837    False 2019-01-17  2019    True
# 1443105    366.906475    False 2019-01-18  2019    None
# 1443640    246.666667    False 2019-05-07  2019    None
# 1443776    280.193237    False 2019-03-25  2019    None
# 1443791    273.409894    False 2019-04-23  2019    None
# 1444311    201.271186    False 2019-02-08  2019    True
# 1444564    223.610224    False 2019-04-22  2019    None
# 1444578    461.904762    False 2019-02-14  2019    True
# 1444667    413.157895    False 2019-02-07  2019    None
# 1445333      2.578740    False 2019-04-08  2019    True
# 1445800    390.449438    False 2019-01-25  2019    True
# 1445940    892.857143    False 2019-04-30  2019    True
# 1446097    400.497512    False 2019-03-29  2019    True
#
# [8351 rows x 11 columns]

# %% [markdown]
# ### 5. Subset the data to zip codes within the City of Seattle.
#
# You'll need to find a list of Seattle zip codes!

# %%
sales_data3['ZipCode'][34]
# Out:
# '98188'

# %%
sales_data3['ZipCode'][0]
# Out:
# '98002'

# %%
ziplist = list(sales_data3['ZipCode'])
zip = list(set(ziplist))
zip

zip1 = list(filter(lambda x: len(x) == 5, zip))

# %%
zip1.sort()
int(zip1[0])
# Out:
# 28028

# %%
zip2 = list(filter(lambda x: int(x)>98100, zip1))
zip2

zip3 = list(filter(lambda x: int(x)<98200, zip2))
zip3
# Out:
# ['98101',
#  '98102',
#  '98103',
#  '98104',
#  '98105',
#  '98106',
#  '98107',
#  '98108',
#  '98109',
#  '98111',
#  '98112',
#  '98113',
#  '98115',
#  '98116',
#  '98117',
#  '98118',
#  '98119',
#  '98121',
#  '98122',
#  '98125',
#  '98126',
#  '98132',
#  '98133',
#  '98134',
#  '98136',
#  '98144',
#  '98146',
#  '98148',
#  '98155',
#  '98157',
#  '98166',
#  '98168',
#  '98176',
#  '98177',
#  '98178',
#  '98188',
#  '98189',
#  '98198',
#  '98199']

# %%
#for i in zip3:
sales_data3['ZipCode'][34]== zip3[-4]
# Out:
# True

# %%
sales_data3['Seattle']= False

def seattle(zipcode):
    for i in zip3:
        if zipcode == i:
            return True

sales_data3['Seattle']= sales_data3['ZipCode'].map(seattle)
sales_data3['Seattle']
# Out:
# 0          None
# 1          None
# 2          None
# 6          None
# 7          None
# 11         None
# 12         None
# 13         None
# 14         None
# 16         None
# 17         None
# 19         None
# 20         None
# 21         None
# 22         None
# 23         None
# 25         None
# 26         None
# 27         None
# 29         None
# 31         None
# 32         None
# 33         None
# 34         True
# 36         True
# 38         None
# 39         None
# 40         None
# 42         None
# 44         None
#            ...
# 1446190    None
# 1446193    True
# 1446194    None
# 1446195    True
# 1446197    True
# 1446198    True
# 1446199    None
# 1446200    True
# 1446201    None
# 1446202    None
# 1446203    None
# 1446204    None
# 1446208    None
# 1446209    None
# 1446210    None
# 1446214    True
# 1446216    None
# 1446217    True
# 1446219    True
# 1446220    True
# 1446221    True
# 1446223    True
# 1446224    None
# 1446225    True
# 1446226    None
# 1446227    True
# 1446228    None
# 1446229    True
# 1446232    None
# 1446233    None
# Name: Seattle, Length: 872106, dtype: object

# %%
sales_data3['Seattle'].value_counts()
# Out:
# True    342918
# Name: Seattle, dtype: int64

# %%
sales_data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index:
# 1446175  616390.0   890.0   09/26/1986      73950           1420   98155
# 1446179  802170.0   935.0   02/15/2011     242000            920   98103
# 1446185  761120.0    75.0   03/27/1986      91000           2400   98177
# 1446189  212404.0  9212.0   09/17/1996     165000           2560   98108
# 1446193  928170.0     5.0   12/11/1986      89950           1630   98116
# 1446195  553830.0   310.0   11/04/2016     500000           1300   98155
# 1446197  553830.0   130.0   10/07/2002     244500           1460   98155
# 1446198  367740.0   680.0   12/12/1986      74000           1980   98108
# 1446200  408330.0  4350.0   11/10/1997     160000           2170   98103
# 1446214  881990.0   480.0   12/22/1999     250000           2250   98105
# 1446217   46100.0  5525.0   12/01/1992     150500            980   98117
# 1446219  336590.0   165.0   09/25/2003     178000            740   98168
# 1446220  882490.0    65.0   07/26/1996     264950           2070   98115
# 1446221  537980.0  3510.0   09/05/1989      89950           1400   98188
# 1446223  948270.0   145.0   04/19/1991     227500           1590   98103
# 1446225  730430.0   710.0   12/29/1986      55950            770   98155
# 1446227   26900.0   880.0   01/12/1988      90000           1220   98199
# 1446229  133680.0   685.0   03/14/1984     112000           2740   98112
#
#          PricePerSqFt  seattle       DATE  Year Seattle
# 34          89.201878    False 2015-07-14  2015    True
# 36         158.685446    False 2015-12-21  2015    True
# 177        270.114943    False 2003-08-01  2003    True
# 178        155.172414    False 1996-03-20  1996    True
# 180        316.091954    False 2013-07-09  2013    True
# 190         15.708812    False 1984-03-05  1984    True
# 191        159.060403    False 2005-05-13  2005    True
# 194        120.134228    False 2002-06-20  2002    True
# 202         96.153846    False 1997-11-13  1997    True
# 203        108.391608    False 1996-05-07  1996    True
# 218        279.936306    False 2003-09-04  2003    True
# 219        150.318471    False 1995-04-20  1995    True
# 250         48.610843    False 2002-02-01  2002    True
# 252        111.445783    False 1994-05-04  1994    True
# 255        113.445378    False 1992-11-03  1992    True
# 259        268.487395    False 2004-08-12  2004    True
# 260        268.487395    False 2004-08-09  2004    True
# 261        133.613445    False 1997-05-08  1997    True
# 272        224.979253    False 2011-06-09  2011    True
# 274        201.244813    False 2003-10-10  2003    True
# 276        195.652174    False 1999-07-08  1999    True
# 286         95.097561    False 1999-10-18  1999    True
# 288        181.451220    False 2007-06-04  2007    True
# 319        149.450549    False 1998-05-22  1998    True
# 320        274.725275    False 2000-03-09  2000    True
# 335         31.993007    False 1983-04-06  1983    True
# 337        136.363636    False 2014-09-24  2014    True
# 340        121.674238    False 1999-12-21  1999    True
# 355        100.000000    False 1999-09-08  1999    True
# 358        128.424658    False 2003-07-15  2003    True
# ...               ...      ...        ...   ...     ...
# 1446137    132.432432    False 1995-01-05  1995    True
# 1446138    102.252252    False 1997-08-21  1997    True
# 1446140    378.308400    False 2001-08-09  2001    True
# 1446141     69.966667    False 1987-06-04  1987    True
# 1446147    361.061947    False 2008-10-27  2008    True
# 1446148     18.041237    False 1985-05-28  1985    True
# 1446153    223.577236    False 2005-04-01  2005    True
# 1446154    151.724138    False 1990-11-27  1990    True
# 1446160     89.805825    False 1995-05-19  1995    True
# 1446162     84.801762    False 1994-05-19  1994    True
# 1446164    103.813559    False 1994-07-27  1994    True
# 1446169     31.562857    False 1985-11-13  1985    True
# 1446175     52.077465    False 1986-09-26  1986    True
# 1446179    263.043478    False 2011-02-15  2011    True
# 1446185     37.916667    False 1986-03-27  1986    True
# 1446189     64.453125    False 1996-09-17  1996    True
# 1446193     55.184049    False 1986-12-11  1986    True
# 1446195    384.615385    False 2016-11-04  2016    True
# 1446197    167.465753    False 2002-10-07  2002    True
# 1446198     37.373737    False 1986-12-12  1986    True
# 1446200     73.732719    False 1997-11-10  1997    True
# 1446214    111.111111    False 1999-12-22  1999    True
# 1446217    153.571429    False 1992-12-01  1992    True
# 1446219    240.540541    False 2003-09-25  2003    True
# 1446220    127.995169    False 1996-07-26  1996    True
# 1446221     64.250000    False 1989-09-05  1989    True
# 1446223    143.081761    False 1991-04-19  1991    True
# 1446225     72.662338    False 1986-12-29  1986    True
# 1446227     73.770492    False 1988-01-12  1988    True
# 1446229     40.875912    False 1984-03-14  1984    True
#
# [342918 rows x 11 columns]

# %%
sales_data3.loc[sales_data3['ZipCode']== zip3[0]]
# Out:
#            Major  Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode  \
# 1409492  84400.0  371.0   08/08/2014     110000           1510   98101
#
#          PricePerSqFt
# 1409492     72.847682

# %%
sales_data3.loc[sales_data3['ZipCode']== zip3[1]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-219-96d9af2626f6> in <module>
# ----> 1 sales_data3.loc[sales_data3['ZipCode'] in zip3]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ### 6. What is the mean price per square foot for a house sold in Seattle in 2019?
#
# Don't just type the answer. Type code that generates the answer as output!

# %%
grouped = sales_data3.groupby(['Seattle', 'Year'])['PricePerSqFt'].mean()
grouped


#sales_data3.loc[sales_data3['Seattle']==True & sales_data3['Year']==2019]
# Out:
# Seattle  Year
# True     1954      0.434783
#          1955     11.585366
#          1959      5.861244
#          1961      4.661638
#          1962      9.673289
#          1963     11.073826
#          1964      6.875179
#          1965     14.076087
#          1966      7.145402
#          1967     16.000000
#          1968     11.965148
#          1969      8.552632
#          1970      9.200445
#          1971      7.934889
#          1972      1.804124
#          1973      6.927880
#          1974     12.376238
#          1975     15.011249
#          1976      7.843137
#          1977     16.298701
#          1978     19.931177
#          1979     23.016768
#          1980      5.924751
#          1981     54.173482
#          1982     49.379959
#          1983     51.548805
#          1984     50.918482
#          1985     52.276541
#          1986     53.747360
#          1987     55.031941
#                     ...
#          1991     96.579571
#          1992    100.254853
#          1993     93.421019
#          1994     95.595331
#          1995     96.772685
#          1996    108.737867
#          1997    114.980247
#          1998    144.758736
#          1999    148.276183
#          2000    170.635483
#          2001    165.391693
#          2002    176.806722
#          2003    186.196812
#          2004    208.045740
#          2005    246.451763
#          2006    272.456162
#          2007    292.357895
#          2008    283.458828
#          2009    247.896147
#          2010    350.025410
#          2011    217.071013
#          2012    223.903871
#          2013    246.667750
#          2014    270.471929
#          2015    301.548389
#          2016    353.056418
#          2017    415.566763
#          2018    456.517212
#          2019    485.710794
#          2021    571.942446
# Name: PricePerSqFt, Length: 63, dtype: float64
